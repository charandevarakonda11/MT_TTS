# %%
# !pip install OpenNMT-py
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 51.8/51.8 kB 4.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 262.8/262.8 kB 10.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 38.6/38.6 MB 20.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 17.0/17.0 MB 100.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 755.6/755.6 MB 2.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 410.6/410.6 MB 3.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 14.1/14.1 MB 109.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 23.7/23.7 MB 87.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 823.6/823.6 kB 41.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 731.7/731.7 MB 2.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 121.6/121.6 MB 6.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.5/56.5 MB 16.5 MB/s eta 0:00:00
# ...

# %%
# !onmt_build_vocab -config config.yaml -n_sample -1
# Out:
# Corpus corpus_1's weight should be given. We default it to 1 for you.
# [2025-03-16 13:35:46,780 INFO] Counter vocab from -1 samples.
# [2025-03-16 13:35:46,780 INFO] n_sample=-1: Build vocab on full datasets.
# [2025-03-16 13:35:46,855 INFO] Counters src: 71
# [2025-03-16 13:35:46,855 INFO] Counters tgt: 10

# %%
# !onmt_train -config train.yaml
# Out:
# [2025-03-16 13:36:47,181 INFO] Missing transforms field for corpus_1 data, set to default: [].
# [2025-03-16 13:36:47,181 WARNING] Corpus corpus_1's weight should be given. We default it to 1 for you.
# [2025-03-16 13:36:47,181 INFO] Missing transforms field for valid data, set to default: [].
# [2025-03-16 13:36:47,181 INFO] Parsed 2 corpora from -data.
# [2025-03-16 13:36:47,182 INFO] Get special vocabs from Transforms: {'src': [], 'tgt': []}.
# [2025-03-16 13:36:47,182 INFO] The first 10 tokens of the vocabs are:['<unk>', '<blank>', '<s>', '</s>', 'two', 'four', 'eight', 'three', 'seven', 'six']
# [2025-03-16 13:36:47,182 INFO] The decoder start token is: <s>
# [2025-03-16 13:36:47,182 INFO] Building model...
# [2025-03-16 13:36:49,731 INFO] Switching model to float32 for amp/apex_amp
# [2025-03-16 13:36:49,731 INFO] Non quantized layer compute is fp32
# [2025-03-16 13:36:50,071 INFO] NMTModel(
#   (encoder): RNNEncoder(
#     (embeddings): Embeddings(
# ...

# %%
# !onmt_translate -model /content/model_step_10000.pt -src /content/test_source.txt -output /content/predictions.txt -gpu 0
# Out:
# [2025-03-16 13:44:57,354 INFO] Loading checkpoint from /content/model_step_10000.pt
# [2025-03-16 13:44:57,742 INFO] Loading data into the model
# [2025-03-16 13:45:01,954 INFO] PRED SCORE: -0.0324, PRED PPL: 1.03 NB SENTENCES: 4609
# Time w/o python interpreter load/terminate:  4.608818769454956
